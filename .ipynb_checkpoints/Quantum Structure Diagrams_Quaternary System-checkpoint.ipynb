# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as patches
import matplotlib.ticker as ticker
import re
from collections import defaultdict
import os

# %% [markdown]
# # List cations and anions, as well as their atomic properties

# %%
el1=['Li','Na','K','Cu','Rb','Ag','Cs','Tl','Au','Fr']  #List of 1+ cations
t1=[454,372,337,1356,312,1234,302,2300,1336,293]        #Melting temperature 
r1=[1.61,2.65,3.69,2.04,4.1,2.375,4.31,2.235,2.66,4.37] #Zunger pseudopotential radii 
v1= [1,1,1,11,1,11,1,3,11,1]                            #Valence electron count
x1= [0.9,0.89,0.80,1.08,0.8,1.07,0.77,1.69,1.19,0.70]   #electronegativity

el3=['Al','Sc','Ti','V','Cr','Mn','Fe','Co','Ni','Ga',
'Y','Zr','Nb','Mo','Tc','Ru','Rh','Pd','In','Sb',
'La','Ce','Pr','Nd','Pm','Sm','Eu','Gd','Tb','Dy',
'Ho','Er','Tm','Yb','Lu','Hf','Ta','W','Re','Os',
'Ir','Pt','Tl','Bi','Au','B']                               #list of 3+ cations 

t3=[832,1811,1938,2190,2176,1517,1812,1768,1728,303,
1773,2128,2770,2890,2473,2700,2239,1823,1773,903,
1193,1077,1208,1297,1300,1345,1100,1585,1629,1680,
1734,1770,1818,1087,1928,2250,3270,3650,3308,3500,
2727,2043,2300,545,1336,2300]                                

r3=[1.675,2.75,2.58,2.43,2.44,2.22,2.11,2.02,2.18,1.695,
2.94,2.825,2.76,2.72,2.65,2.605,2.52,2.45,2.05,1.765,
3.08,4.50,4.48,3.99,3.99,4.14,3.94,3.91,3.89,3.67,
3.65,3.63,3.60,3.59,3.37,2.91,2.79,2.735,2.68,2.65,
2.628,2.70,2.235,1.997,2.66,0.785]                           

v3=[3,3,4,5,6,7,8,9,10,3,
3,4,5,6,7,8,9,10,3,5,
3,3,3,3,3,3,3,3,3,3,
3,3,3,3,3,4,5,6,7,8,
9,10,3,5,11,3]                                         

x3=[1.64,1.5,1.86,2.22,2.00,2.04,1.67,1.72,1.76,1.70,
1.41,1.70,2.03,1.94,2.18,1.97,1.99,2.08,1.63,2.14,
1.35,1.1,1.1,1.2,1.15,1.2,1.15,1.1,1.2,1.15,
1.2,1.2,1.2,1.1,1.2,1.73,1.94,1.79,2.06,1.85,
1.87,1.91,1.69,2.14,1.19,1.9]

el4=['P']                    # List of 4+ cations
t4=[870]                              
r4=[1.24]#                           
v4=[5]
x4=[2.32]

el2=['S','Se']             # List of 2- anion
t2=[392,490]               
r2=[1.10,1.285]            
v2=[6,6]                  
x2=[2.65,2.54]

# %% [markdown]
# # Generate all potential quaternary compositions and calculate their properties based on atomic parameters

# %%
compound_forming = open('Compound Forming.txt','w') #This is for collecting all generated Quaternary compositions
cf_2decimal = open('cf_2decimal.txt','w')        #The same content, but with only 2 decimals for data extraction

i=0
j=0
l=0
m=0
k=0
y=0

for i in range (0,len(el1)):      #iteration through all possible combinations of el1,el2,el3,and el4
    for j in range (0,len(el3)):
        for k in range (0,len(el4)):
            for l in range (0,len(el2)):
                m=m+1
                name = el1[i]+el3[j]+el4[k]+"2"+el2[l]+"6"+' ' ### Displays the name of the interated compund
                #print(name)     
                num = [t1[i],t3[j],t4[k],t2[l]]
                sorted_numbers = sorted(num, reverse=True)
                nmax,n2nd,n3rd,n4th=sorted_numbers
                
                delta_t = (float(nmax/n2nd)+float(nmax/n3rd)+float(nmax/n4th)+float(n2nd/n3rd)+
                float(n2nd/n4th)+float(n3rd/n4th))/6
                #print(f"{delta_t:.2f}")
            
                Absdelta_r = (
                    abs(r1[i]-r3[j])+abs(r1[i]-r4[k])+abs(r1[i]-r2[l])+
                    abs(r3[j]-r4[k])+abs(r3[j]-r2[l])+
                    abs(r4[k]-r2[l]))/6  #Calculates <abs(ΔR)>
                #print(f"{Absdelta_r:.2f}")

                Absdelta_Nv = (
                    abs(v1[i]-v3[j])+abs(v1[i]-v4[k])+abs(v1[i]-v2[l])+
                    abs(v3[j]-v4[k])+abs(v3[j]-v2[l])+
                    abs(v4[k]-v2[l]))/6  #Calculates <abs(ΔNv)>
                #print(f"{Absdelta_Nv:.2f}")

                Absdelta_Neg = (
                    abs(x1[i]-x3[j])+abs(x1[i]-x4[k])+abs(x1[i]-x2[l])+
                    abs(x3[j]-x4[k])+abs(x3[j]-x2[l])+
                    abs(x4[k]-x2[l]))/6  #Calculates <abs(ΔX)>
                #print(f"{Absdelta_Neg:.2f}")
                
                outlist=str(m)+' '+name+str(delta_t)+' '+str(Absdelta_r)+' '+str(Absdelta_Nv)+ ' '+str(Absdelta_Neg)+' '+str(r1[i])+' '+ str(r3[j])+ '\n'  ### creates a list of values with variables "name",
                compound_forming.write(outlist) #writes outlist into the file we created in the beginning 

                outlist_2d=f"{m} {name} {delta_t:.2f} {Absdelta_r:.2f} {Absdelta_Nv:.2f} {Absdelta_Neg:.2f} {r1[i]} {r3[j]}\n"
                cf_2decimal.write(outlist_2d) #writes outlist into the file we created in the beginning
                
                
compound_forming.close() # closes text file
cf_2decimal.close()

# %% [markdown]
# # List all ICSD entries that fulfill our search standard

# %%
icsdfile = open('CF ICSD Structure.txt','w') 
unclassified = open('CF unclassified total.txt','w')

# %%
with open ('Compound Forming.txt', "r") as myfile:
    data = myfile.readlines()

# %%
#Desired structure type and corresponding compound name in parentheses
AgVP2S6 = ("AgVP2S6", "AgCrP2S6")
AgInP2S6 = ("AgInP2S6","AgScP2S6","CuInP2Se6","AgInP2Se6","AgGaP2Se6","AgErP2Se6","AgScP2Se6","AgTmP2Se6","LiScP2S6","CuBiP2Se6")
FePS3    = ("AgCrP2Se6","AgAlP2Se6")
FePSe3   = ("CuAlP2Se6",)    #do not delete the "," after CuAlP2Se6

not_in_Structure_types = ("CuInP2S6","CuCrP2S6","CuScP2S6","AgBiP2Se6") 

#Outlier structure type and corresponding compound name in parentheses
LiAlP2S6 = ('LiAlP2S6',)
NaYbP2S6 = ("NaYbP2S6","AgBiP2S6","NaErP2S6","NaLuP2S6","NaTbP2S6","NaYP2S6","TlInP2Se6")
KBiP2Se6 = ("KBiP2Se6","NaSmP2S6","NaCeP2S6","NaSbP2S6","NaPrP2S6","KCeP2S6","KPrP2S6","TlCeP2S6","RbLaP2S6","NaLaP2S6","NaCeP2Se6","KLaP2Se6","TlCeP2Se6","TlLaP2Se6","TlLaP2S6","TlPrP2Se6","TlBiP2Se6","KBiP2S6")
KSbP2Se6 = ("KSbP2S6","KSbP2Se6","NaSbP2S6","KBiP2S6","TlBiP2S6","TlInP2S6","TlSbP2S6","KBiP2Se6","TlSbP2Se6","TlDyP2Se6","TlErP2Se6","TlSmP2Se6","TlYP2Se6","TlBiP2S6")
CsCeP2S6 = ("CsCeP2S6","CsCeP2Se6","CsLaP2S6")

structure_types = (AgVP2Se6,AgVP2S6,AgInP2S6,FePS3,FePSe3,LiAlP2S6,NaYbP2S6,KBiP2Se6,KSbP2Se6,CsCeP2S6)
S_types_name = ("AgVP2Se6","AgVP2S6","AgInP2S6","FePS3","FePSe3","LiAlP2S6","NaYbP2S6","KBiP2Se6","KSbP2Se6","CsCeP2S6") # just for name

# %%
structure_dict = {'AgVP2Se6':"AgVP2Se6", 'CuVP2S6':"AgVP2Se6", 'CuCrP2Se6':"AgVP2Se6", "AgVP2S6":"AgVP2S6", "AgCrP2S6":"AgVP2S6", "CuInP2S6":0}

# %%
count = 0
foundcount = 0
for line in data:
    words = line.split()
    to_write = words[1]
    count = count + 1
    if words[1] in structure_dict:
        foundcount = foundcount + 1
        print(words[1], foundcount, count)
        #write to the file of found structure types
    else:
        pass
        #write to the other file
# Out:
# CuVP2S6 1 283
# CuCrP2Se6 2 286
# CuInP2S6 3 313
# AgVP2S6 4 467
# AgVP2Se6 5 468
# AgCrP2S6 6 469

# %%
for i in range(len(structure_types)):
    for j in range(len(structure_types[i])):
        for k in range(len(data1)):
            
            S = str(structure_types[i][j])
            entry = str(data1[k][1]) + ' ' + str(data1[k][2]) + ' ' + str(data1[k][3]) + ' ' + str(data1[k][4]) + ' ' + str(data1[k][5]) + ' ' + str(i) + ' ' + str(S_types_name[i]) + ' ' + str(data1[k][6]) +  ' ' + str(data1[k][7])

            if S == data1[k][1]:
                if entry not in written_entries:
                    my_file.write(entry + '\n')
                    written_entries.add(entry)
                    print(f"myfile {i} {j} {k}")
            #elif data1[k][1]!=S:
            else:
                line1 = str(data1[k][1]) + ' ' + str(data1[k][2]) + ' ' + str(data1[k][3]) + ' ' + str(data1[k][4]) + ' ' + str(data1[k][5]) + ' ' + str(data1[k][6]) + ' ' + str(data1[k][7])
                if line1 not in written_entries:
                    my_file1.write(line1 + '\n')
                    written_entries.add(line1)
                    print(f"myfile1 {i} {j} {k}")
       
for l in range(0,(len(not_in_Structure_types))):
    for m in range(0,len(data1)):
        S = str(not_in_Structure_types[l])
        if (S == data1[m][1]) == True:
            not_in_S_types=str(l)+' '+ str(data1[m][1])+' '+str(data1[m][2])+' '+str(data1[m][3])+' '+ str(data1[m][4])+' '+str(data1[m][5])+' '+str(data1[m][6])+' '+str(data1[m][7])+'\n'
            my_file2.write(not_in_S_types)    
                    

my_file.close()
my_file1.close()
my_file2.close()
# Out:
# myfile1 0 0 0
# myfile1 0 0 1
# myfile1 0 0 2
# myfile1 0 0 3
# myfile1 0 0 4
# myfile1 0 0 5
# myfile1 0 0 6
# myfile1 0 0 7
# myfile1 0 0 8
# myfile1 0 0 9
# myfile1 0 0 10
# myfile1 0 0 11
# myfile1 0 0 12
# myfile1 0 0 13
# myfile1 0 0 14
# myfile1 0 0 15
# myfile1 0 0 16
# myfile1 0 0 17
# myfile1 0 0 18
# myfile1 0 0 19
# myfile1 0 0 20
# myfile1 0 0 21
# myfile1 0 0 22
# myfile1 0 0 23
# myfile1 0 0 24
# myfile1 0 0 25
# myfile1 0 0 26
# myfile1 0 0 27
# myfile1 0 0 28
# myfile1 0 0 29
# myfile1 0 0 30
# myfile1 0 0 31
# myfile1 0 0 32
# myfile1 0 0 33
# myfile1 0 0 34
# myfile1 0 0 35
# myfile1 0 0 36
# myfile1 0 0 37
# myfile1 0 0 38
# myfile1 0 0 39
# myfile1 0 0 40
# myfile1 0 0 41
# myfile1 0 0 42
# myfile1 0 0 43
# myfile1 0 0 44
# myfile1 0 0 45
# myfile1 0 0 46
# myfile1 0 0 47
# myfile1 0 0 48
# myfile1 0 0 49
# myfile1 0 0 50
# myfile1 0 0 51
# myfile1 0 0 52
# myfile1 0 0 53
# myfile1 0 0 54
# myfile1 0 0 55
# myfile1 0 0 56
# myfile1 0 0 57
# myfile1 0 0 58
# myfile1 0 0 59
# myfile1 0 0 60
# myfile1 0 0 61
# myfile1 0 0 62
# myfile1 0 0 63
# myfile1 0 0 64
# myfile1 0 0 65
# myfile1 0 0 66
# myfile1 0 0 67
# myfile1 0 0 68
# myfile1 0 0 69
# myfile1 0 0 70
# myfile1 0 0 71
# myfile1 0 0 72
# myfile1 0 0 73
# myfile1 0 0 74
# myfile1 0 0 75
# myfile1 0 0 76
# myfile1 0 0 77
# myfile1 0 0 78
# myfile1 0 0 79
# myfile1 0 0 80
# myfile1 0 0 81
# myfile1 0 0 82
# myfile1 0 0 83
# myfile1 0 0 84
# myfile1 0 0 85
# myfile1 0 0 86
# myfile1 0 0 87
# myfile1 0 0 88
# myfile1 0 0 89
# myfile1 0 0 90
# myfile1 0 0 91
# myfile1 0 0 92
# myfile1 0 0 93
# myfile1 0 0 94
# myfile1 0 0 95
# myfile1 0 0 96
# myfile1 0 0 97
# myfile1 0 0 98
# myfile1 0 0 99
# myfile1 0 0 100
# myfile1 0 0 101
# myfile1 0 0 102
# myfile1 0 0 103
# myfile1 0 0 104
# myfile1 0 0 105
# myfile1 0 0 106
# myfile1 0 0 107
# myfile1 0 0 108
# myfile1 0 0 109
# myfile1 0 0 110
# myfile1 0 0 111
# myfile1 0 0 112
# myfile1 0 0 113
# myfile1 0 0 114
# myfile1 0 0 115
# myfile1 0 0 116
# myfile1 0 0 117
# myfile1 0 0 118
# myfile1 0 0 119
# myfile1 0 0 120
# myfile1 0 0 121
# myfile1 0 0 122
# myfile1 0 0 123
# myfile1 0 0 124
# myfile1 0 0 125
# myfile1 0 0 126
# myfile1 0 0 127
# myfile1 0 0 128
# myfile1 0 0 129
# myfile1 0 0 130
# myfile1 0 0 131
# myfile1 0 0 132
# myfile1 0 0 133
# myfile1 0 0 134
# myfile1 0 0 135
# myfile1 0 0 136
# myfile1 0 0 137
# myfile1 0 0 138
# myfile1 0 0 139
# myfile1 0 0 140
# myfile1 0 0 141
# myfile1 0 0 142
# myfile1 0 0 143
# myfile1 0 0 144
# myfile1 0 0 145
# myfile1 0 0 146
# myfile1 0 0 147
# myfile1 0 0 148
# myfile1 0 0 149
# myfile1 0 0 150
# myfile1 0 0 151
# myfile1 0 0 152
# myfile1 0 0 153
# myfile1 0 0 154
# myfile1 0 0 155
# myfile1 0 0 156
# myfile1 0 0 157
# myfile1 0 0 158
# myfile1 0 0 159
# myfile1 0 0 160
# myfile1 0 0 161
# myfile1 0 0 162
# myfile1 0 0 163
# myfile1 0 0 164
# myfile1 0 0 165
# myfile1 0 0 166
# myfile1 0 0 167
# myfile1 0 0 168
# myfile1 0 0 169
# myfile1 0 0 170
# myfile1 0 0 171
# myfile1 0 0 172
# myfile1 0 0 173
# myfile1 0 0 174
# myfile1 0 0 175
# myfile1 0 0 176
# myfile1 0 0 177
# myfile1 0 0 178
# myfile1 0 0 179
# myfile1 0 0 180
# myfile1 0 0 181
# myfile1 0 0 182
# myfile1 0 0 183
# myfile1 0 0 184
# myfile1 0 0 185
# myfile1 0 0 186
# myfile1 0 0 187
# myfile1 0 0 188
# myfile1 0 0 189
# myfile1 0 0 190
# myfile1 0 0 191
# myfile1 0 0 192
# myfile1 0 0 193
# myfile1 0 0 194
# myfile1 0 0 195
# myfile1 0 0 196
# myfile1 0 0 197
# myfile1 0 0 198
# myfile1 0 0 199
# myfile1 0 0 200
# myfile1 0 0 201
# myfile1 0 0 202
# myfile1 0 0 203
# myfile1 0 0 204
# myfile1 0 0 205
# myfile1 0 0 206
# myfile1 0 0 207
# myfile1 0 0 208
# myfile1 0 0 209
# myfile1 0 0 210
# myfile1 0 0 211
# myfile1 0 0 212
# myfile1 0 0 213
# myfile1 0 0 214
# myfile1 0 0 215
# myfile1 0 0 216
# myfile1 0 0 217
# myfile1 0 0 218
# myfile1 0 0 219
# myfile1 0 0 220
# myfile1 0 0 221
# myfile1 0 0 222
# myfile1 0 0 223
# myfile1 0 0 224
# myfile1 0 0 225
# myfile1 0 0 226
# myfile1 0 0 227
# myfile1 0 0 228
# myfile1 0 0 229
# myfile1 0 0 230
# myfile1 0 0 231
# myfile1 0 0 232
# myfile1 0 0 233
# myfile1 0 0 234
# myfile1 0 0 235
# myfile1 0 0 236
# myfile1 0 0 237
# myfile1 0 0 238
# myfile1 0 0 239
# myfile1 0 0 240
# myfile1 0 0 241
# myfile1 0 0 242
# myfile1 0 0 243
# myfile1 0 0 244
# myfile1 0 0 245
# myfile1 0 0 246
# myfile1 0 0 247
# myfile1 0 0 248
# myfile1 0 0 249
# myfile1 0 0 250
# myfile1 0 0 251
# myfile1 0 0 252
# myfile1 0 0 253
# myfile1 0 0 254
# myfile1 0 0 255
# myfile1 0 0 256
# myfile1 0 0 257
# myfile1 0 0 258
# myfile1 0 0 259
# myfile1 0 0 260
# myfile1 0 0 261
# myfile1 0 0 262
# myfile1 0 0 263
# myfile1 0 0 264
# myfile1 0 0 265
# myfile1 0 0 266
# myfile1 0 0 267
# myfile1 0 0 268
# myfile1 0 0 269
# myfile1 0 0 270
# myfile1 0 0 271
# myfile1 0 0 272
# myfile1 0 0 273
# myfile1 0 0 274
# myfile1 0 0 275
# myfile1 0 0 276
# myfile1 0 0 277
# myfile1 0 0 278
# myfile1 0 0 279
# myfile1 0 0 280
# myfile1 0 0 281
# myfile1 0 0 282
# myfile1 0 0 283
# myfile1 0 0 284
# myfile1 0 0 285
# myfile1 0 0 286
# myfile1 0 0 287
# myfile1 0 0 288
# myfile1 0 0 289
# myfile1 0 0 290
# myfile1 0 0 291
# myfile1 0 0 292
# myfile1 0 0 293
# myfile1 0 0 294
# myfile1 0 0 295
# myfile1 0 0 296
# myfile1 0 0 297
# myfile1 0 0 298
# myfile1 0 0 299
# myfile1 0 0 300
# myfile1 0 0 301
# myfile1 0 0 302
# myfile1 0 0 303
# myfile1 0 0 304
# myfile1 0 0 305
# myfile1 0 0 306
# myfile1 0 0 307
# myfile1 0 0 308
# myfile1 0 0 309
# myfile1 0 0 310
# myfile1 0 0 311
# myfile1 0 0 312
# myfile1 0 0 313
# myfile1 0 0 314
# myfile1 0 0 315
# myfile1 0 0 316
# myfile1 0 0 317
# myfile1 0 0 318
# myfile1 0 0 319
# myfile1 0 0 320
# myfile1 0 0 321
# myfile1 0 0 322
# myfile1 0 0 323
# myfile1 0 0 324
# myfile1 0 0 325
# myfile1 0 0 326
# myfile1 0 0 327
# myfile1 0 0 328
# myfile1 0 0 329
# myfile1 0 0 330
# myfile1 0 0 331
# myfile1 0 0 332
# myfile1 0 0 333
# myfile1 0 0 334
# myfile1 0 0 335
# myfile1 0 0 336
# myfile1 0 0 337
# myfile1 0 0 338
# myfile1 0 0 339
# myfile1 0 0 340
# myfile1 0 0 341
# myfile1 0 0 342
# myfile1 0 0 343
# myfile1 0 0 344
# myfile1 0 0 345
# myfile1 0 0 346
# myfile1 0 0 347
# myfile1 0 0 348
# myfile1 0 0 349
# myfile1 0 0 350
# myfile1 0 0 351
# myfile1 0 0 352
# myfile1 0 0 353
# myfile1 0 0 354
# myfile1 0 0 355
# myfile1 0 0 356
# myfile1 0 0 357
# myfile1 0 0 358
# myfile1 0 0 359
# myfile1 0 0 360
# myfile1 0 0 361
# myfile1 0 0 362
# myfile1 0 0 363
# myfile1 0 0 364
# myfile1 0 0 365
# myfile1 0 0 366
# myfile1 0 0 367
# myfile1 0 0 368
# myfile1 0 0 369
# myfile1 0 0 370
# myfile1 0 0 371
# myfile1 0 0 372
# myfile1 0 0 373
# myfile1 0 0 374
# myfile1 0 0 375
# myfile1 0 0 376
# myfile1 0 0 377
# myfile1 0 0 378
# myfile1 0 0 379
# myfile1 0 0 380
# myfile1 0 0 381
# myfile1 0 0 382
# myfile1 0 0 383
# myfile1 0 0 384
# myfile1 0 0 385
# myfile1 0 0 386
# myfile1 0 0 387
# myfile1 0 0 388
# myfile1 0 0 389
# myfile1 0 0 390
# myfile1 0 0 391
# myfile1 0 0 392
# myfile1 0 0 393
# myfile1 0 0 394
# myfile1 0 0 395
# myfile1 0 0 396
# myfile1 0 0 397
# myfile1 0 0 398
# myfile1 0 0 399
# myfile1 0 0 400
# myfile1 0 0 401
# myfile1 0 0 402
# myfile1 0 0 403
# myfile1 0 0 404
# myfile1 0 0 405
# myfile1 0 0 406
# myfile1 0 0 407
# myfile1 0 0 408
# myfile1 0 0 409
# myfile1 0 0 410
# myfile1 0 0 411
# myfile1 0 0 412
# myfile1 0 0 413
# myfile1 0 0 414
# myfile1 0 0 415
# myfile1 0 0 416
# myfile1 0 0 417
# myfile1 0 0 418
# myfile1 0 0 419
# myfile1 0 0 420
# myfile1 0 0 421
# myfile1 0 0 422
# myfile1 0 0 423
# myfile1 0 0 424
# myfile1 0 0 425
# myfile1 0 0 426
# myfile1 0 0 427
# myfile1 0 0 428
# myfile1 0 0 429
# myfile1 0 0 430
# myfile1 0 0 431
# myfile1 0 0 432
# myfile1 0 0 433
# myfile1 0 0 434
# myfile1 0 0 435
# myfile1 0 0 436
# myfile1 0 0 437
# myfile1 0 0 438
# myfile1 0 0 439
# myfile1 0 0 440
# myfile1 0 0 441
# myfile1 0 0 442
# myfile1 0 0 443
# myfile1 0 0 444
# myfile1 0 0 445
# myfile1 0 0 446
# myfile1 0 0 447
# myfile1 0 0 448
# myfile1 0 0 449
# myfile1 0 0 450
# myfile1 0 0 451
# myfile1 0 0 452
# myfile1 0 0 453
# myfile1 0 0 454
# myfile1 0 0 455
# myfile1 0 0 456
# myfile1 0 0 457
# myfile1 0 0 458
# myfile1 0 0 459
# myfile1 0 0 460
# myfile1 0 0 461
# myfile1 0 0 462
# myfile1 0 0 463
# myfile1 0 0 464
# myfile1 0 0 465
# myfile1 0 0 466
# myfile 0 0 467
# myfile1 0 0 468
# myfile1 0 0 469
# myfile1 0 0 470
# myfile1 0 0 471
# myfile1 0 0 472
# myfile1 0 0 473
# myfile1 0 0 474
# myfile1 0 0 475
# myfile1 0 0 476
# myfile1 0 0 477
# myfile1 0 0 478
# myfile1 0 0 479
# myfile1 0 0 480
# myfile1 0 0 481
# myfile1 0 0 482
# myfile1 0 0 483
# myfile1 0 0 484
# myfile1 0 0 485
# myfile1 0 0 486
# myfile1 0 0 487
# myfile1 0 0 488
# myfile1 0 0 489
# myfile1 0 0 490
# myfile1 0 0 491
# myfile1 0 0 492
# myfile1 0 0 493
# myfile1 0 0 494
# myfile1 0 0 495
# myfile1 0 0 496
# myfile1 0 0 497
# myfile1 0 0 498
# myfile1 0 0 499
# myfile1 0 0 500
# myfile1 0 0 501
# myfile1 0 0 502
# myfile1 0 0 503
# myfile1 0 0 504
# myfile1 0 0 505
# myfile1 0 0 506
# myfile1 0 0 507
# myfile1 0 0 508
# myfile1 0 0 509
# myfile1 0 0 510
# myfile1 0 0 511
# myfile1 0 0 512
# myfile1 0 0 513
# myfile1 0 0 514
# myfile1 0 0 515
# myfile1 0 0 516
# myfile1 0 0 517
# myfile1 0 0 518
# myfile1 0 0 519
# myfile1 0 0 520
# myfile1 0 0 521
# myfile1 0 0 522
# myfile1 0 0 523
# myfile1 0 0 524
# myfile1 0 0 525
# myfile1 0 0 526
# myfile1 0 0 527
# myfile1 0 0 528
# myfile1 0 0 529
# myfile1 0 0 530
# myfile1 0 0 531
# myfile1 0 0 532
# myfile1 0 0 533
# myfile1 0 0 534
# myfile1 0 0 535
# myfile1 0 0 536
# myfile1 0 0 537
# myfile1 0 0 538
# myfile1 0 0 539
# myfile1 0 0 540
# myfile1 0 0 541
# myfile1 0 0 542
# myfile1 0 0 543
# myfile1 0 0 544
# myfile1 0 0 545
# myfile1 0 0 546
# myfile1 0 0 547
# myfile1 0 0 548
# myfile1 0 0 549
# myfile1 0 0 550
# myfile1 0 0 551
# myfile1 0 0 552
# myfile1 0 0 553
# myfile1 0 0 554
# myfile1 0 0 555
# myfile1 0 0 556
# myfile1 0 0 557
# myfile1 0 0 558
# myfile1 0 0 559
# myfile1 0 0 560
# myfile1 0 0 561
# myfile1 0 0 562
# myfile1 0 0 563
# myfile1 0 0 564
# myfile1 0 0 565
# myfile1 0 0 566
# myfile1 0 0 567
# myfile1 0 0 568
# myfile1 0 0 569
# myfile1 0 0 570
# myfile1 0 0 571
# myfile1 0 0 572
# myfile1 0 0 573
# myfile1 0 0 574
# myfile1 0 0 575
# myfile1 0 0 576
# myfile1 0 0 577
# myfile1 0 0 578
# myfile1 0 0 579
# myfile1 0 0 580
# myfile1 0 0 581
# myfile1 0 0 582
# myfile1 0 0 583
# myfile1 0 0 584
# myfile1 0 0 585
# myfile1 0 0 586
# myfile1 0 0 587
# myfile1 0 0 588
# myfile1 0 0 589
# myfile1 0 0 590
# myfile1 0 0 591
# myfile1 0 0 592
# myfile1 0 0 593
# myfile1 0 0 594
# myfile1 0 0 595
# myfile1 0 0 596
# myfile1 0 0 597
# myfile1 0 0 598
# myfile1 0 0 599
# myfile1 0 0 600
# myfile1 0 0 601
# myfile1 0 0 602
# myfile1 0 0 603
# myfile1 0 0 604
# myfile1 0 0 605
# myfile1 0 0 606
# myfile1 0 0 607
# myfile1 0 0 608
# myfile1 0 0 609
# myfile1 0 0 610
# myfile1 0 0 611
# myfile1 0 0 612
# myfile1 0 0 613
# myfile1 0 0 614
# myfile1 0 0 615
# myfile1 0 0 616
# myfile1 0 0 617
# myfile1 0 0 618
# myfile1 0 0 619
# myfile1 0 0 620
# myfile1 0 0 621
# myfile1 0 0 622
# myfile1 0 0 623
# myfile1 0 0 624
# myfile1 0 0 625
# myfile1 0 0 626
# myfile1 0 0 627
# myfile1 0 0 628
# myfile1 0 0 629
# myfile1 0 0 630
# myfile1 0 0 631
# myfile1 0 0 632
# myfile1 0 0 633
# myfile1 0 0 634
# myfile1 0 0 635
# myfile1 0 0 636
# myfile1 0 0 637
# myfile1 0 0 638
# myfile1 0 0 639
# myfile1 0 0 640
# myfile1 0 0 641
# myfile1 0 0 642
# myfile1 0 0 643
# myfile1 0 0 644
# myfile1 0 0 645
# myfile1 0 0 646
# myfile1 0 0 647
# myfile1 0 0 648
# myfile1 0 0 649
# myfile1 0 0 650
# myfile1 0 0 651
# myfile1 0 0 652
# myfile1 0 0 653
# myfile1 0 0 654
# myfile1 0 0 655
# myfile1 0 0 656
# myfile1 0 0 657
# myfile1 0 0 658
# myfile1 0 0 659
# myfile1 0 0 660
# myfile1 0 0 661
# myfile1 0 0 662
# myfile1 0 0 663
# myfile1 0 0 664
# myfile1 0 0 665
# myfile1 0 0 666
# myfile1 0 0 667
# myfile1 0 0 668
# myfile1 0 0 669
# myfile1 0 0 670
# myfile1 0 0 671
# myfile1 0 0 672
# myfile1 0 0 673
# myfile1 0 0 674
# myfile1 0 0 675
# myfile1 0 0 676
# myfile1 0 0 677
# myfile1 0 0 678
# myfile1 0 0 679
# myfile1 0 0 680
# myfile1 0 0 681
# myfile1 0 0 682
# myfile1 0 0 683
# myfile1 0 0 684
# myfile1 0 0 685
# myfile1 0 0 686
# myfile1 0 0 687
# myfile1 0 0 688
# myfile1 0 0 689
# myfile1 0 0 690
# myfile1 0 0 691
# myfile1 0 0 692
# myfile1 0 0 693
# myfile1 0 0 694
# myfile1 0 0 695
# myfile1 0 0 696
# myfile1 0 0 697
# myfile1 0 0 698
# myfile1 0 0 699
# myfile1 0 0 700
# myfile1 0 0 701
# myfile1 0 0 702
# myfile1 0 0 703
# myfile1 0 0 704
# myfile1 0 0 705
# myfile1 0 0 706
# myfile1 0 0 707
# myfile1 0 0 708
# myfile1 0 0 709
# myfile1 0 0 710
# myfile1 0 0 711
# myfile1 0 0 712
# myfile1 0 0 713
# myfile1 0 0 714
# myfile1 0 0 715
# myfile1 0 0 716
# myfile1 0 0 717
# myfile1 0 0 718
# myfile1 0 0 719
# myfile1 0 0 720
# myfile1 0 0 721
# myfile1 0 0 722
# myfile1 0 0 723
# myfile1 0 0 724
# myfile1 0 0 725
# myfile1 0 0 726
# myfile1 0 0 727
# myfile1 0 0 728
# myfile1 0 0 729
# myfile1 0 0 730
# myfile1 0 0 731
# myfile1 0 0 732
# myfile1 0 0 733
# myfile1 0 0 734
# myfile1 0 0 735
# myfile1 0 0 736
# myfile1 0 0 737
# myfile1 0 0 738
# myfile1 0 0 739
# myfile1 0 0 740
# myfile1 0 0 741
# myfile1 0 0 742
# myfile1 0 0 743
# myfile1 0 0 744
# myfile1 0 0 745
# myfile1 0 0 746
# myfile1 0 0 747
# myfile1 0 0 748
# myfile1 0 0 749
# myfile1 0 0 750
# myfile1 0 0 751
# myfile1 0 0 752
# myfile1 0 0 753
# myfile1 0 0 754
# myfile1 0 0 755
# myfile1 0 0 756
# myfile1 0 0 757
# myfile1 0 0 758
# myfile1 0 0 759
# myfile1 0 0 760
# myfile1 0 0 761
# myfile1 0 0 762
# myfile1 0 0 763
# myfile1 0 0 764
# myfile1 0 0 765
# myfile1 0 0 766
# myfile1 0 0 767
# myfile1 0 0 768
# myfile1 0 0 769
# myfile1 0 0 770
# myfile1 0 0 771
# myfile1 0 0 772
# myfile1 0 0 773
# myfile1 0 0 774
# myfile1 0 0 775
# myfile1 0 0 776
# myfile1 0 0 777
# myfile1 0 0 778
# myfile1 0 0 779
# myfile1 0 0 780
# myfile1 0 0 781
# myfile1 0 0 782
# myfile1 0 0 783
# myfile1 0 0 784
# myfile1 0 0 785
# myfile1 0 0 786
# myfile1 0 0 787
# myfile1 0 0 788
# myfile1 0 0 789
# myfile1 0 0 790
# myfile1 0 0 791
# myfile1 0 0 792
# myfile1 0 0 793
# myfile1 0 0 794
# myfile1 0 0 795
# myfile1 0 0 796
# myfile1 0 0 797
# myfile1 0 0 798
# myfile1 0 0 799
# myfile1 0 0 800
# myfile1 0 0 801
# myfile1 0 0 802
# myfile1 0 0 803
# myfile1 0 0 804
# myfile1 0 0 805
# myfile1 0 0 806
# myfile1 0 0 807
# myfile1 0 0 808
# myfile1 0 0 809
# myfile1 0 0 810
# myfile1 0 0 811
# myfile1 0 0 812
# myfile1 0 0 813
# myfile1 0 0 814
# myfile1 0 0 815
# myfile1 0 0 816
# myfile1 0 0 817
# myfile1 0 0 818
# myfile1 0 0 819
# myfile1 0 0 820
# myfile1 0 0 821
# myfile1 0 0 822
# myfile1 0 0 823
# myfile1 0 0 824
# myfile1 0 0 825
# myfile1 0 0 826
# myfile1 0 0 827
# myfile1 0 0 828
# myfile1 0 0 829
# myfile1 0 0 830
# myfile1 0 0 831
# myfile1 0 0 832
# myfile1 0 0 833
# myfile1 0 0 834
# myfile1 0 0 835
# myfile1 0 0 836
# myfile1 0 0 837
# myfile1 0 0 838
# myfile1 0 0 839
# myfile1 0 0 840
# myfile1 0 0 841
# myfile1 0 0 842
# myfile1 0 0 843
# myfile1 0 0 844
# myfile1 0 0 845
# myfile1 0 0 846
# myfile1 0 0 847
# myfile1 0 0 848
# myfile1 0 0 849
# myfile1 0 0 850
# myfile1 0 0 851
# myfile1 0 0 852
# myfile1 0 0 853
# myfile1 0 0 854
# myfile1 0 0 855
# myfile1 0 0 856
# myfile1 0 0 857
# myfile1 0 0 858
# myfile1 0 0 859
# myfile1 0 0 860
# myfile1 0 0 861
# myfile1 0 0 862
# myfile1 0 0 863
# myfile1 0 0 864
# myfile1 0 0 865
# myfile1 0 0 866
# myfile1 0 0 867
# myfile1 0 0 868
# myfile1 0 0 869
# myfile1 0 0 870
# myfile1 0 0 871
# myfile1 0 0 872
# myfile1 0 0 873
# myfile1 0 0 874
# myfile1 0 0 875
# myfile1 0 0 876
# myfile1 0 0 877
# myfile1 0 0 878
# myfile1 0 0 879
# myfile1 0 0 880
# myfile1 0 0 881
# myfile1 0 0 882
# myfile1 0 0 883
# myfile1 0 0 884
# myfile1 0 0 885
# myfile1 0 0 886
# myfile1 0 0 887
# myfile1 0 0 888
# myfile1 0 0 889
# myfile1 0 0 890
# myfile1 0 0 891
# myfile1 0 0 892
# myfile1 0 0 893
# myfile1 0 0 894
# myfile1 0 0 895
# myfile1 0 0 896
# myfile1 0 0 897
# myfile1 0 0 898
# myfile1 0 0 899
# myfile1 0 0 900
# myfile1 0 0 901
# myfile1 0 0 902
# myfile1 0 0 903
# myfile1 0 0 904
# myfile1 0 0 905
# myfile1 0 0 906
# myfile1 0 0 907
# myfile1 0 0 908
# myfile1 0 0 909
# myfile1 0 0 910
# myfile1 0 0 911
# myfile1 0 0 912
# myfile1 0 0 913
# myfile1 0 0 914
# myfile1 0 0 915
# myfile1 0 0 916
# myfile1 0 0 917
# myfile1 0 0 918
# myfile1 0 0 919
# myfile 0 1 282
# myfile1 0 1 467
# myfile 0 2 285
# myfile 1 0 466
# myfile 1 1 468
# myfile 2 0 496
# myfile 2 1 462
# myfile 2 2 313
# myfile 2 3 497
# myfile 2 4 479
# myfile 2 5 523
# myfile 2 6 463
# myfile 2 7 525
# myfile 2 8 2
# myfile 2 9 363
# myfile 3 0 469
# myfile 3 1 461
# myfile 4 0 277
# myfile 5 0 0
# myfile 6 0 158
# myfile 6 1 546
# myfile 6 2 154
# myfile 6 3 160
# myfile 6 4 148
# myfile 6 5 112
# myfile 6 6 681
# myfile 7 0 271
# myfile 7 1 142
# myfile 7 2 134
# myfile 7 3 130
# myfile 7 4 136
# myfile 7 5 226
# myfile 7 6 228
# myfile 7 7 686
# myfile 7 8 408
# myfile 7 9 132
# myfile 7 10 135
# myfile 7 11 225
# myfile 7 12 687
# myfile 7 13 685
# myfile 7 14 684
# myfile 7 15 689
# myfile 7 16 731
# myfile 7 17 270
# myfile 8 0 222
# myfile 8 1 223
# myfile 8 2 130
# myfile 8 3 270
# myfile 8 4 730
# myfile 8 5 680
# myfile 8 6 682
# myfile 8 7 271
# myfile 8 8 683
# myfile 8 9 703
# myfile 8 10 707
# myfile 8 11 695
# myfile 8 12 665
# myfile 9 0 594
# myfile 9 1 595
# myfile 9 2 592

# %% [markdown]
# # Quantum Structure Diagram (Radii vs Melting temperature)

# %%
S_types = ("AgVP2Se6","AgVP2S6","AgInP2S6","FePS3","FePSe3","LiAlP2S6","NaYbP2S6","KBiP2Se6","KSbP2Se6","CsCeP2S6")
def to_subscript(s):
    return re.sub(r'(\d)', r'$_{\1}$', s)

S_types_with_subscripts = [to_subscript(name) for name in S_types]

inlist = np.loadtxt('CF ICSD Structure.txt',dtype = float, usecols=(1,2,3,4,5),delimiter=' ') 
inlist_char = np.loadtxt('CF ICSD Structure.txt',dtype = str, usecols=(0),delimiter=' ')  #column-0: compound name
inlist_val = np.loadtxt('CF ICSD Structure.txt',dtype = int, usecols=(5),delimiter=' ')  #column-5: the number corresponds to the structure type, this is define color coating
not_Classified = np.loadtxt('CF ICSD no S-Types.txt',dtype = float, usecols=(2,3,4,5),delimiter=' ')
not_inlist = np.loadtxt('CF unclassified total.txt',dtype = float, usecols=(1,2,3,4),delimiter= ' ')

fig = plt.plot()
ax = plt.subplot()
ax.scatter((not_inlist[:,0]),(not_inlist[:,1]), edgecolor = 'black', s = 15, label = "Unreported",marker = 'o',facecolors='none') #ax.scatter:create a scatter plot
ax.scatter((not_Classified[:,0]),(not_Classified[:,1]), c = 'darkorchid',edgecolor = 'black', s = 70, label = "Unclassified", marker = 'o',)

inlist = np.array(inlist)
color_map = {
    0: ('magenta', 'o',70,1),   #AgVP2Se6
    1: ('orange', 'o',70,1),       #AgVP2S6
    2: ('lime', 'o',70,1),         #AgInP2S6
    3: ('deepskyblue', 'o',70,1), #FePS3
    4: ('yellow', 'o',70,1),}      #FePSe3

inlist_val = inlist[:, 4].astype(int)
excluded_indices = [2,13,14]  #2,13,14 represent the line in inlist: 'CuCrP2Se6','LiScP2S6','CuBiP2Se6'

for i in range(len(inlist)):#plot the structure from ICSD 
    x=inlist[i, 0]
    y=inlist[i, 1]  
    S = str(inlist_char[i])       
    if S == 'CuCrP2Se6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='deepskyblue', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='magenta', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2)
        
    if S == 'CuBiP2Se6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='lime', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='darkorchid', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2) 
       
    if S == 'LiScP2S6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='lime', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='red', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2)
    if i in excluded_indices:
        continue  # Skip these indices
    
    label = inlist_val[i]       # Extract label as integer
    color_marker_tuple = color_map.get(label, ('red', '^',80,1.0))  # Default to red triangle
    color, marker, size, alpha = color_marker_tuple  # Unpack the tuple
    label_with_subscript = S_types_with_subscripts[inlist_val[i]]
    ax.scatter(x,y, c=color, s=size, edgecolors='black', marker=marker, label=label_with_subscript, alpha=alpha)
        

def legend_without_duplicate_labels(figure):  # defines a function named "legend_without_duplicate_labels(figure)" how labels are input in to the legend and removes duplicate legend labels
    handles, labels = ax.get_legend_handles_labels()  # retirieves label values and stores as handles
    by_label = dict(zip(labels, handles))  #organizes dictionary with zip by order in which the label is first passed and stores new dictionary as by_label. sets labels as the key and handles as the values
    
    lgd = ax.legend(by_label.values(), by_label.keys(), loc='center left', bbox_to_anchor=(1, 0.5),title = "Structure Type")  #sets lgd as the list in the dic with no duplicate keys. loc and bbox will define the location of the legend box. 


legend_without_duplicate_labels(ax)

#Title and labels
#plt.title(r'$A^{1+}A^{\prime^ 3+}$' + "Compound Forming Map", fontsize = 20)   
plt.xlabel(r'$<T_{>}/T_{<}>$',fontsize = 20)
#plt.ylabel("ΔR mean (a.u.)", fontsize = 20)
plt.ylabel(r"$\overline{|ΔR|}$ (a.u.)", fontsize=20)

#x and y tick labels
ax.set_xticklabels(ax.get_xticks(),fontsize = 15)
ax.set_yticklabels(ax.get_yticks(),fontsize = 15)

ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))

#Save and show figure
ax.figure.set_figwidth(10)     
plt.savefig("Plot-1+3+-T&R ", dpi= 600, format=None, metadata=None,
        bbox_inches='tight', pad_inches=.4,
        facecolor='auto', edgecolor='auto',
        backend=None,)

plt.show()
# Out:
# /tmp/ipykernel_1948/2331250737.py:34: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='deepskyblue', edgecolor='black')
# /tmp/ipykernel_1948/2331250737.py:35: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='magenta', edgecolor='black')
# /tmp/ipykernel_1948/2331250737.py:46: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='lime', edgecolor='black')
# /tmp/ipykernel_1948/2331250737.py:47: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='red', edgecolor='black')
# /tmp/ipykernel_1948/2331250737.py:40: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='lime', edgecolor='black')
# /tmp/ipykernel_1948/2331250737.py:41: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='darkorchid', edgecolor='black')
# /tmp/ipykernel_1948/2331250737.py:76: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(),fontsize = 15)
# /tmp/ipykernel_1948/2331250737.py:77: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(),fontsize = 15)

# %% [markdown]
# # Quantum Structure Diagram (Melting temperature vs Valence electron)

# %%
S_types = ("AgVP2Se6","AgVP2S6","AgInP2S6","FePS3","FePSe3","LiAlP2S6","NaYbP2S6","KBiP2Se6","KSbP2Se6","CsCeP2S6")
def to_subscript(s):
    return re.sub(r'(\d)', r'$_{\1}$', s)

S_types_with_subscripts = [to_subscript(name) for name in S_types]

inlist = np.loadtxt('CF ICSD Structure.txt',dtype = float, usecols=(1,2,3,4,5),delimiter=' ') 
inlist_char = np.loadtxt('CF ICSD Structure.txt',dtype = str, usecols=(0),delimiter=' ')  #column-0: compound name
inlist_val = np.loadtxt('CF ICSD Structure.txt',dtype = int, usecols=(5),delimiter=' ')  #column-5: the number corresponds to the structure type, this is define color coating
not_Classified = np.loadtxt('CF ICSD no S-Types.txt',dtype = float, usecols=(2,3,4,5),delimiter=' ')
not_inlist = np.loadtxt('CF unclassified total.txt',dtype = float, usecols=(1,2,3,4),delimiter= ' ')

fig = plt.plot()
ax = plt.subplot()
ax.scatter((not_inlist[:,0]),(not_inlist[:,2]), edgecolor = 'black', s = 15, label = "Unreported",marker = 'o',facecolors='none') #ax.scatter:create a scatter plot
ax.scatter((not_Classified[:,0]),(not_Classified[:,2]), c = 'darkorchid',edgecolor = 'black', s = 70, label = "Unclassified", marker = 'o',)

inlist = np.array(inlist)
color_map = {
    0: ('magenta', 'o',70,1),   #AgVP2Se6
    1: ('orange', 'o',70,1),       #AgVP2S6
    2: ('lime', 'o',70,1),         #AgInP2S6
    3: ('deepskyblue', 'o',70,1), #FePS3
    4: ('yellow', 'o',70,1),}     #FePSe3

inlist_val = inlist[:, 4].astype(int)
excluded_indices = [2,13,14]  #2,13,14 represent the line in inlist: 'CuCrP2Se6','LiScP2S6','CuBiP2Se6'

for i in range(len(inlist)):#plot the structure from ICSD 
    x=inlist[i, 0]
    y=inlist[i, 2]
    S = str(inlist_char[i])       
    if S == 'CuCrP2Se6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.05, 0, 180, color='deepskyblue', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.05, 180, 360, color='magenta', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2)
        
    if S == 'CuBiP2Se6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.05, 0, 180, color='lime', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.05, 180, 360, color='darkorchid', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2) 
       
    if S == 'LiScP2S6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.05, 0, 180, color='lime', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.05, 180, 360, color='red', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2)
    if i in excluded_indices:
        continue  # Skip these indices
        
    label = inlist_val[i]                                    # Extract label as integer
    color_marker_tuple = color_map.get(label, ('red', '^',80,1.0))  # Default to red triangle
    color, marker, size, alpha = color_marker_tuple  # Unpack the tuple
    label_with_subscript = S_types_with_subscripts[inlist_val[i]]
    ax.scatter(x,y, c=color, s=size, edgecolors='black', marker=marker, label=label_with_subscript, alpha=alpha)


def legend_without_duplicate_labels(figure):  # defines a function named "legend_without_duplicate_labels(figure)" how labels are input in to the legend and removes duplicate legend labels
    handles, labels = ax.get_legend_handles_labels()  # retirieves label values and stores as handles
    by_label = dict(zip(labels, handles))  #organizes dictionary with zip by order in which the label is first passed and stores new dictionary as by_label. sets labels as the key and handles as the values
    
    lgd = ax.legend(by_label.values(), by_label.keys(), loc='center left', bbox_to_anchor=(1, 0.5),title = "Structure Type")  #sets lgd as the list in the dic with no duplicate keys. loc and bbox will define the location of the legend box. 


legend_without_duplicate_labels(ax)
 
plt.xlabel(r'$<T_{>}/T_{<}>$',fontsize = 20)
plt.ylabel(r"$\overline{|\Delta N_{v}|}$", fontsize=20)

ax.set_xticklabels(ax.get_xticks(),fontsize = 15)
ax.set_yticklabels(ax.get_yticks(),fontsize = 15)
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))

#Save and show figure
ax.figure.set_figwidth(8)     
plt.savefig("Plot-1+3+-T&Nv ", dpi= 600, format=None, metadata=None,
        bbox_inches='tight', pad_inches=.4,
        facecolor='auto', edgecolor='auto',
        backend=None,)

plt.show()
# Out:
# /tmp/ipykernel_1948/189068550.py:34: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.05, 0, 180, color='deepskyblue', edgecolor='black')
# /tmp/ipykernel_1948/189068550.py:35: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.05, 180, 360, color='magenta', edgecolor='black')
# /tmp/ipykernel_1948/189068550.py:46: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.05, 0, 180, color='lime', edgecolor='black')
# /tmp/ipykernel_1948/189068550.py:47: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.05, 180, 360, color='red', edgecolor='black')
# /tmp/ipykernel_1948/189068550.py:40: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.05, 0, 180, color='lime', edgecolor='black')
# /tmp/ipykernel_1948/189068550.py:41: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.05, 180, 360, color='darkorchid', edgecolor='black')
# /tmp/ipykernel_1948/189068550.py:72: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(),fontsize = 15)
# /tmp/ipykernel_1948/189068550.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(),fontsize = 15)

# %% [markdown]
# # Quantum Structure Diagram (Radii vs Valence electron)

# %%
S_types = ("AgVP2Se6","AgVP2S6","AgInP2S6","FePS3","FePSe3","LiAlP2S6","NaYbP2S6","KBiP2Se6","KSbP2Se6","CsCeP2S6")
def to_subscript(s):
    return re.sub(r'(\d)', r'$_{\1}$', s)

S_types_with_subscripts = [to_subscript(name) for name in S_types]

inlist = np.loadtxt('CF ICSD Structure.txt',dtype = float, usecols=(1,2,3,4,5),delimiter=' ') 
inlist_char = np.loadtxt('CF ICSD Structure.txt',dtype = str, usecols=(0),delimiter=' ')  #column-0: compound name
inlist_val = np.loadtxt('CF ICSD Structure.txt',dtype = int, usecols=(5),delimiter=' ')  #column-5: the number corresponds to the structure type, this is define color coating
not_Classified = np.loadtxt('CF ICSD no S-Types.txt',dtype = float, usecols=(2,3,4,5),delimiter=' ')
not_inlist = np.loadtxt('CF unclassified total.txt',dtype = float, usecols=(1,2,3,4),delimiter= ' ')

fig = plt.plot()
ax = plt.subplot()
ax.scatter((not_inlist[:,1]),(not_inlist[:,2]), edgecolor = 'black', s = 15, label = "Unreported",marker = 'o',facecolors='none') #ax.scatter:create a scatter plot
ax.scatter((not_Classified[:,1]),(not_Classified[:,2]), c = 'darkorchid',edgecolor = 'black', s = 70, label = "Unclassified", marker = 'o',)

inlist = np.array(inlist)
color_map = {
    0: ('magenta', 'o',70,1),   #AgVP2Se6
    1: ('orange', 'o',70,1),       #AgVP2S6
    2: ('lime', 'o',70,1),         #AgInP2S6
    3: ('deepskyblue', 'o',70,1), #FePS3
    4: ('yellow', 'o',70,1),}     #FePSe3


inlist_val = inlist[:, 4].astype(int)
excluded_indices = [2,13,14]  #2,13,14 represent the line in inlist: 'CuCrP2Se6','LiScP2S6','CuBiP2Se6'

for i in range(len(inlist)):#plot the structure from ICSD 
    x=inlist[i, 1]
    y=inlist[i, 2]
    S = str(inlist_char[i])       
    if S == 'CuCrP2Se6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='deepskyblue', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='magenta', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2)
        
    if S == 'CuBiP2Se6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='lime', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='darkorchid', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2) 
       
    if S == 'LiScP2S6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='lime', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='red', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2)
    
    if i in excluded_indices:
        continue  # Skip these indices
        
    label = inlist_val[i]                                    # Extract label as integer
    color_marker_tuple = color_map.get(label, ('red', '^',80,1.0))  # Default to red triangle
    color, marker, size, alpha = color_marker_tuple  # Unpack the tuple
    label_with_subscript = S_types_with_subscripts[inlist_val[i]]
    ax.scatter(x,y, c=color, s=size, edgecolors='black', marker=marker, label=label_with_subscript, alpha=alpha)

def legend_without_duplicate_labels(figure):  # defines a function named "legend_without_duplicate_labels(figure)" how labels are input in to the legend and removes duplicate legend labels
    handles, labels = ax.get_legend_handles_labels()  # retirieves label values and stores as handles
    by_label = dict(zip(labels, handles))  #organizes dictionary with zip by order in which the label is first passed and stores new dictionary as by_label. sets labels as the key and handles as the values
    
    lgd = ax.legend(by_label.values(), by_label.keys(), loc='center left', bbox_to_anchor=(1, 0.5),title = "Structure Type")  #sets lgd as the list in the dic with no duplicate keys. loc and bbox will define the location of the legend box. 


legend_without_duplicate_labels(ax)
 
plt.xlabel(r"$\overline{|ΔR|}$ (a.u.)", fontsize=20)
plt.ylabel(r"$\overline{|\Delta N_{v}|}$", fontsize=20)

#x and y tick labels
ax.set_xticklabels(ax.get_xticks(),fontsize = 15)
ax.set_yticklabels(ax.get_yticks(),fontsize = 15)
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))

#Save and show figure
ax.figure.set_figwidth(8)     
plt.savefig("Plot-1+3+-R&Nv", dpi= 600, format=None, metadata=None,
        bbox_inches='tight', pad_inches=.4,
        facecolor='auto', edgecolor='auto',
        backend=None,)

plt.show()
# Out:
# /tmp/ipykernel_1948/248261203.py:35: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='deepskyblue', edgecolor='black')
# /tmp/ipykernel_1948/248261203.py:36: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='magenta', edgecolor='black')
# /tmp/ipykernel_1948/248261203.py:47: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='lime', edgecolor='black')
# /tmp/ipykernel_1948/248261203.py:48: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='red', edgecolor='black')
# /tmp/ipykernel_1948/248261203.py:41: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.03, 90, 270, color='lime', edgecolor='black')
# /tmp/ipykernel_1948/248261203.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.03, 270, 90, color='darkorchid', edgecolor='black')
# /tmp/ipykernel_1948/248261203.py:74: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(),fontsize = 15)
# /tmp/ipykernel_1948/248261203.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(),fontsize = 15)

# %% [markdown]
# # Quantum Structure Diagram (Radii vs Electronegativity)

# %%
S_types = ("AgVP2Se6","AgVP2S6","AgInP2S6","FePS3","FePSe3","LiAlP2S6","NaYbP2S6","KBiP2Se6","KSbP2Se6","CsCeP2S6")
def to_subscript(s):
    return re.sub(r'(\d)', r'$_{\1}$', s)

S_types_with_subscripts = [to_subscript(name) for name in S_types]

inlist = np.loadtxt('CF ICSD Structure.txt',dtype = float, usecols=(1,2,3,4,5),delimiter=' ') 
inlist_char = np.loadtxt('CF ICSD Structure.txt',dtype = str, usecols=(0),delimiter=' ')  #column-0: compound name
inlist_val = np.loadtxt('CF ICSD Structure.txt',dtype = int, usecols=(5),delimiter=' ')  #column-5: the number corresponds to the structure type, this is define color coating
not_Classified = np.loadtxt('CF ICSD no S-Types.txt',dtype = float, usecols=(2,3,4,5),delimiter=' ')
not_inlist = np.loadtxt('CF unclassified total.txt',dtype = float, usecols=(1,2,3,4),delimiter= ' ')

fig = plt.plot()
ax = plt.subplot()
ax.scatter((not_inlist[:,1]),(not_inlist[:,3]), edgecolor = 'black', s = 15, label = "Unreported",marker = 'o',facecolors='none') #ax.scatter:create a scatter plot
ax.scatter((not_Classified[:,1]),(not_Classified[:,3]), c = 'darkorchid',edgecolor = 'black', s = 70, label = "Unclassified", marker = 'o',)

inlist = np.array(inlist)
color_map = { 
    0: ('magenta', 'o',70,1),      #AgVP2Se6
    1: ('orange', 'o',70,1),       #AgVP2S6
    2: ('lime', 'o',70,1),         #AgInP2S6
    3: ('deepskyblue', 'o',70,1), #FePS3
    4: ('yellow', 'o',70,1),}     #FePSe3


inlist_val = inlist[:, 4].astype(int)
excluded_indices = [2,13,14]  #2,13,14 represent the line in inlist: 'CuCrP2Se6','LiScP2S6','CuBiP2Se6'

for i in range(len(inlist)):#plot the structure from ICSD 
    x=inlist[i, 1]
    y=inlist[i, 3]  
    S = str(inlist_char[i])       
    if S == 'CuCrP2Se6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.015, 90, 270, color='deepskyblue', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.015, 270, 90, color='magenta', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2)
        
    if S == 'CuBiP2Se6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.015, 90, 270, color='lime', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.015, 270, 90, color='darkorchid', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2) 
       
    if S == 'LiScP2S6':   #It has 2 diff structure type, so color coated with two colors.  
        half_1 = patches.Wedge((x, y), 0.015, 90, 270, color='lime', edgecolor='black')
        half_2 = patches.Wedge((x, y), 0.015, 270, 90, color='red', edgecolor='black')
        ax.add_patch(half_1)
        ax.add_patch(half_2)
    if i in excluded_indices:
        continue  # Skip these indices
    
    label = inlist_val[i]                                    # Extract label as integer
    color_marker_tuple = color_map.get(label, ('red', '^',80,1.0))  # Default to red triangle
    color, marker, size, alpha = color_marker_tuple  # Unpack the tuple
    label_with_subscript = S_types_with_subscripts[inlist_val[i]]
    ax.scatter(x,y, c=color, s=size, edgecolors='black', marker=marker, label=label_with_subscript, alpha=alpha)
        

def legend_without_duplicate_labels(figure):  # defines a function named "legend_without_duplicate_labels(figure)" how labels are input in to the legend and removes duplicate legend labels
    handles, labels = ax.get_legend_handles_labels()  # retirieves label values and stores as handles
    by_label = dict(zip(labels, handles))  #organizes dictionary with zip by order in which the label is first passed and stores new dictionary as by_label. sets labels as the key and handles as the values
    
    lgd = ax.legend(by_label.values(), by_label.keys(), loc='center left', bbox_to_anchor=(1, 0.5),title = "Structure Type")  #sets lgd as the list in the dic with no duplicate keys. loc and bbox will define the location of the legend box. 


legend_without_duplicate_labels(ax)

plt.xlabel(r"$\overline{|ΔR|}$ (a.u.)", fontsize=20)
plt.ylabel(r"$\overline{|\Delta X|}$ [(eV)$^{\frac{1}{2}}$]", fontsize=20)

#x and y tick labels
ax.set_xticklabels(ax.get_xticks(),fontsize = 15)
ax.set_yticklabels(ax.get_yticks(),fontsize = 15)
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))

ax.set_xlim(0.15, 2.3)  # Replace xmin and xmax with your desired values
ax.set_ylim(0.4, 1.25)  # Replace ymin and ymax with your desired values

#Save and show figure
ax.figure.set_figwidth(10)     
plt.savefig("Plot-1+3+-R&X ", dpi= 600, format=None, metadata=None,
        bbox_inches='tight', pad_inches=.4,
        facecolor='auto', edgecolor='auto',
        backend=None,)

plt.show()
# Out:
# /tmp/ipykernel_1948/1865348571.py:35: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.015, 90, 270, color='deepskyblue', edgecolor='black')
# /tmp/ipykernel_1948/1865348571.py:36: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.015, 270, 90, color='magenta', edgecolor='black')
# /tmp/ipykernel_1948/1865348571.py:47: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.015, 90, 270, color='lime', edgecolor='black')
# /tmp/ipykernel_1948/1865348571.py:48: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.015, 270, 90, color='red', edgecolor='black')
# /tmp/ipykernel_1948/1865348571.py:41: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_1 = patches.Wedge((x, y), 0.015, 90, 270, color='lime', edgecolor='black')
# /tmp/ipykernel_1948/1865348571.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   half_2 = patches.Wedge((x, y), 0.015, 270, 90, color='darkorchid', edgecolor='black')
# /tmp/ipykernel_1948/1865348571.py:74: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(),fontsize = 15)
# /tmp/ipykernel_1948/1865348571.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(),fontsize = 15)

# %% [markdown]
# # The all codes below are only for data extraction

# %%
ICSD_entry = ("AgVP2Se6","CuVP2S6","CuCrP2Se6","AgVP2S6","AgCrP2S6","AgInP2S6","AgScP2S6","CuInP2Se6","AgInP2Se6","AgGaP2Se6",
                "AgErP2Se6","AgScP2Se6","AgTmP2Se6","LiScP2S6","CuBiP2Se6","AgCrP2Se6","AgAlP2Se6","CuAlP2Se6","CuInP2S6","CuCrP2S6",
                "CuScP2S6","AgBiP2Se6","LiAlP2S6","NaYbP2S6","AgBiP2S6","NaErP2S6","NaLuP2S6","NaTbP2S6","NaYP2S6","TlInP2Se6",
               "KBiP2Se6","NaSmP2S6","NaCeP2S6","NaSbP2S6","NaPrP2S6","KCeP2S6","KPrP2S6","TlCeP2S6","RbLaP2S6","NaLaP2S6","NaCeP2Se6","KLaP2Se6","TlCeP2Se6","TlLaP2Se6","TlLaP2S6","TlPrP2Se6","TlBiP2Se6","KBiP2S6",
               "KSbP2S6","KSbP2Se6","NaSbP2S6","KBiP2S6","TlBiP2S6","TlInP2S6","TlSbP2S6","KBiP2Se6","TlSbP2Se6","TlDyP2Se6","TlErP2Se6","TlSmP2Se6","TlYP2Se6","TlBiP2S6",
               "CsCeP2S6","CsCeP2Se6","CsLaP2S6")

# %%
# Open the file cf_2decimal for reading
with open('cf_2decimal.txt', 'r') as cf_file:
    lines = cf_file.readlines()
         
with open('Candidate_1.txt', 'w') as Candidate_1, \
     open('Candidate_Ma.txt', 'w') as Candidate_Ma, \
     open('Candidate_T_R_Ma.txt', 'w') as Candidate_T_R_Ma, \
     open('Candidate_T_R_Mi.txt', 'w') as Candidate_T_R_Mi, \
     open('Candidate_R_EN_Ma.txt', 'w') as Candidate_R_EN_Ma, \
     open('Candidate_R_EN_Ma_ex.txt', 'w') as Candidate_R_EN_Ma_ex, \
     open('Candidate_R_EN_Mi.txt', 'w') as Candidate_R_EN_Mi, \
     open('Candidate_T_V.txt', 'w') as Candidate_T_V, \
     open('Candidate_T_V417.txt', 'w') as Candidate_T_V417, \
     open('Candidate_T_V317.txt', 'w') as Candidate_T_V317, \
     open('Candidate_T_V300.txt', 'w') as Candidate_T_V300, \
     open('Candidate_T_V283.txt', 'w') as Candidate_T_V283, \
     open('Candidate_T_Vspace_317417.txt', 'w') as Candidate_T_Vspace_317417, \
     open('Candidate_R_V.txt', 'w') as Candidate_R_V, \
     open('Candidate_R_V417.txt', 'w') as Candidate_R_V417, \
     open('Candidate_R_V317.txt', 'w') as Candidate_R_V317, \
     open('Candidate_R_V300.txt', 'w') as Candidate_R_V300, \
     open('Candidate_R_V283.txt', 'w') as Candidate_R_V283, \
     open('Candidate_R_Vspace_317417.txt', 'w') as Candidate_R_Vspace_317417:

    for line in lines:
        # Split the line into components
        parts = line.split()
        m = parts[0]  
        name = parts[1]  
        delta_t = float(parts[2])
        Absdelta_r = float(parts[3])
        Absdelta_Nv = float(parts[4])
        Absdelta_Neg = float(parts[5])
        
        # Check the conditions for Candidate
        if (1.60 <= delta_t <= 2.90 and
            0.40 <= Absdelta_r <= 1.40 and
            Absdelta_Nv in [2.83, 3.00, 3.17, 4.17] and
            0.7 <= Absdelta_Neg <= 1.1 and
            name not in ICSD_entry):  
            Candidate_1.write(line)  # All unreported filtered by T,R,V,EN

        if (1.60 <= delta_t <= 2.90 and
            0.40 <= Absdelta_r <= 1.05 and
            Absdelta_Nv in [3.00, 3.17, 4.17] and
            0.7 <= Absdelta_Neg <= 0.95 and
            name not in ICSD_entry):  
            Candidate_Ma.write(line)  # All unreported filtered by T,R,V,EN-Majority
                    
        if (1.60 <= delta_t <= 2.90 and
            0.40 <= Absdelta_r <= 1.05 and
            name not in ICSD_entry):  
            Candidate_T_R_Ma.write(line)     #T_R_Majority
            
        if (2.10 <= delta_t <= 2.20 and  
            1.34 <= Absdelta_r <= 1.40 and
            name not in ICSD_entry):  
            Candidate_T_R_Mi.write(line)     # T_R_Minority  
        
        if (0.40 <= Absdelta_r <= 1.05 and
            0.7 <= Absdelta_Neg <= 1.1 and
            name not in ICSD_entry):  
            Candidate_R_EN_Ma.write(line)     #R_EN_Majority
            
        if (0.40 <= Absdelta_r <= 1.05 and
            0.7 <= Absdelta_Neg <= 0.95 and
            name not in ICSD_entry):  
            Candidate_R_EN_Ma_ex.write(line)     #R_EN_Majority_exclude LiScP2S6
        
        if (1.34 <= Absdelta_r <= 1.40 and
            0.90 <= Absdelta_Neg <= 0.94 and
            name not in ICSD_entry):  
            Candidate_R_EN_Mi.write(line)     #R_EN_Minority
                
        if (1.60 <= delta_t <= 2.90 and
            Absdelta_Nv in [2.83, 3.00, 3.17, 4.17] and
            name not in ICSD_entry): 
            Candidate_T_V.write(line)         #T_V
            
        if (1.60 <= delta_t <= 2.90 and \
            Absdelta_Nv == 4.17 and \
            name not in ICSD_entry): 
            Candidate_T_V417.write(line)         #T_V = 4.17
            
        if (1.60 <= delta_t <= 2.90 and \
            Absdelta_Nv == 3.17 and \
            name not in ICSD_entry): 
            Candidate_T_V317.write(line)         #T_V = 3.17
            
        if (1.60 <= delta_t <= 2.90 and \
            Absdelta_Nv == 3.00 and \
            name not in ICSD_entry): 
            Candidate_T_V300.write(line)         #T_V = 3.00

        if (2.63 <= delta_t <= 2.69 and \
            Absdelta_Nv == 2.83 and \
            name not in ICSD_entry): 
            Candidate_T_V283.write(line)         #T_V = 2.83

        if (1.60 <= delta_t <= 2.90 and \
            3.17 < Absdelta_Nv < 4.17 and \
            name not in ICSD_entry): 
            Candidate_T_Vspace_317417.write(line)         #T_V = space between 3.17 - 4.17
                            
        if (0.40 <= Absdelta_r <= 1.40 and
            Absdelta_Nv in [2.83, 3.00, 3.17, 4.17] and
            name not in ICSD_entry):  
            Candidate_R_V.write(line)         #R_V
        
        if (0.40 <= Absdelta_r <= 1.40 and \
            Absdelta_Nv == 4.17 and \
            name not in ICSD_entry):  
            Candidate_R_V417.write(line)         #R_V = 4.17
        
        if (0.40 <= Absdelta_r <= 1.40 and \
            Absdelta_Nv == 3.17 and \
            name not in ICSD_entry):  
            Candidate_R_V317.write(line)         #R_V = 3.17
        
        if (0.40 <= Absdelta_r <= 1.40 and \
            Absdelta_Nv == 3.00 and \
            name not in ICSD_entry):  
            Candidate_R_V300.write(line)         #R_V = 3.00
        
        if (0.40 <= Absdelta_r <= 1.40 and \
            Absdelta_Nv == 2.83 and \
            name not in ICSD_entry):  
            Candidate_R_V283.write(line)         #R_V = 2.83
            
        if (0.40 <= Absdelta_r <= 1.40 and \
            3.17 < Absdelta_Nv < 4.17 and \
            name not in ICSD_entry):  
            Candidate_R_Vspace_317417.write(line)         #R_V = space between 3.17 - 4.17

# %% [markdown]
# # Calculate the frequency and collect the filenames and data into count.txt

# %%
# Define the filenames
filenames = [
    'Candidate_T_R_Ma.txt',
    'Candidate_T_R_Mi.txt',
    'Candidate_R_EN_Ma.txt',
    # 'Candidate_R_EN_Ma_ex.txt',
    'Candidate_R_EN_Mi.txt',
    'Candidate_T_V.txt',
    # 'Candidate_T_V417.txt',
    # 'Candidate_T_V317.txt',
    # 'Candidate_T_V300.txt',
    # 'Candidate_T_V283.txt',
    # 'Candidate_T_Vspace_317417.txt',
    'Candidate_R_V.txt',
    # 'Candidate_R_V417.txt',
    # 'Candidate_R_V317.txt',
    # 'Candidate_R_V300.txt',
    # 'Candidate_R_V283.txt',
    # 'Candidate_R_Vspace_317417.txt',
]

# Dictionary to store compound counts, their source files, and the full lines
compound_count = defaultdict(lambda: {'count': 0, 'files': set(), 'lines': set()})

# Function to convert numbers in compound names to subscript format
def to_subscript(text):
    # Define the mapping of digits to subscript characters
    subscript_map = str.maketrans('0123456789', '₀₁₂₃₄₅₆₇₈₉')
    return text.translate(subscript_map)

# Read each file and update the counts
for filename in filenames:
    if os.path.exists(filename):  # Check if the file exists
        with open(filename, 'r') as file:
            for line in file:
                columns = line.strip().split()  # Split line into columns
                if columns:  # Check if there's at least one column
                    compound_name = columns[1]  # Get the compound name
                    formatted_name = to_subscript(compound_name)  # Convert the name to subscript format
                    compound_count[formatted_name]['count'] += 1  # Increment count
                    compound_count[formatted_name]['files'].add(filename)  # Add filename
                    compound_count[formatted_name]['lines'].add(line.strip())  # Store the full line

# Sort compounds by count in descending order
sorted_compounds = sorted(compound_count.items(), key=lambda item: item[1]['count'], reverse=True)

# Write to 'count.txt'
with open('count.txt', 'w') as count_file:
    count_file.write('Compound Name\tCount\tFiles\tLines\n')  # Write header
    for compound, data in sorted_compounds:
        files_list = ', '.join(data['files'])  # Join filenames
        lines_content = ' | '.join(sorted(data['lines']))  # Join unique lines and sort them for consistency
        count_file.write(f"{compound}\t{data['count']}\t{files_list}\t{lines_content}\n")  # Write compound info
